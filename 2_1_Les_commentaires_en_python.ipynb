# %% [markdown]
# <a href="https://colab.research.google.com/github/haythem-rehouma/python1/blob/main/2_1_Les_commentaires_en_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 - Exemple de commentaire en Python

# %%
# Ceci est un commentaire
# Ce commentaire explique l'instruction print
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # 2 - Les commentaires multi-lignes - méthode 1

# %%
"""
Ce texte n'est pas un commentaire officiel,
mais peut être utilisé pour documenter du code.
"""
print("Bonjour, Python !")
# Out:
# Bonjour, Python !

# %% [markdown]
# # 3 - Les commentaires multi-lignes - méthode 2

# %%
# Ligne 1 de commentaire
# Ligne 2 de commentaire
# Ligne 3 de commentaire
